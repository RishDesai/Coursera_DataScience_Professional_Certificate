# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author:
# Rish Desai

# %% [markdown]
# This is a Notebook containing a brief intro into some of the elements of Data Science.

# %% [markdown]
# **Objectives:**
# - Identify the important languages used in Data Science
# - Identify important libraries that can be used for Data Science
# - See some basic math expressions from Python

# %% [markdown]
# In Data Science, there are several key languages that are used. Some of the most popular ones include:
# 1.  Python
# 2.  R Studio
# 3.  SQL --> A querying language used in various SQL Servers such as Postgre SQl and My SQL

# %% [markdown]
# With these languages, there are also several important libraries used to be able to carry out the Data Science tasks. These include:
# 1.  Pandas --> Python
# 2.  Numpy --> Python
# 3.  Seaborn --> Python
# 4.  Sci-kit Learn --> Python
# 5.  GGplot  --> R Studio

# %% [markdown]
# In order to carry out several of the Data Science taks, a wide variety of tools are used. Some examples of these are:
#
# |Data Science Tools|
# |:--------:|
# |Apache Spark|
# |SaaS|
# |Tableau|

# %% [markdown]
# ### In Python, several tasks invovle basic mathematical operations such as the following ones.

# %%
#Here is a simple basic Python operation that can be solved.
(4**2) + 34
# Out:
# 50

# %%
#Here is an example of converting 440 minutes into hours
minutes = 440
hours = minutes / 60
hours
# Out:
# 7.333333333333333
